# %%
import pandas
pandas.set_option('display.height', 200)
intersect = pandas.read_csv("intersect.tsv",sep="\t",index_col=0)
intersect = intersect.drop_duplicates()
intersect
# Out:
# height has been deprecated.
#         cognitiveatlas       neurosynth
# 0         anticipation     anticipation
# 2         anticipation     anticipatory
# 3               belief          beliefs
# 5            addiction        addiction
# 6             learning         learning
# 8             learning         learners
# 10             empathy          empathy
# 11            movement        movements
# 13          adaptation         adaptive
# 17       comprehension    comprehensive
# 19          activation         activity
# 29              naming           naming
# 34               habit      habituation
# 35          attachment       attachment
# 36             thought         thoughts
# 38                goal            goals
# 40             reading          reading
# 41             reading          readers
# 43              eating           eating
# 44      representation  representations
# 47        coordination     coordination
# 51                rule            rules
# ...
